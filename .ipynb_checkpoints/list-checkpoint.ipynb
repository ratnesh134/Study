# %% [markdown]
# # Python List

# %% [markdown]
# ## What is Lists ?
#
# list is a data type where you can store multiple items under 1 name. list act like a dynamic arrays which means you can add more items on the fly.

# %% [markdown]
# ## Array VS List
#
# Fixed (Array) VS Dynamic Size (list)
#
# Convenience (Homogeneous) --> Hetrogeneous
#
# Speed of Execution is slow in list than Array
#
# Python list occupies more memory than array
